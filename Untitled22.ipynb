# %% [markdown]
# <a href="https://colab.research.google.com/github/Joanmei/Engage-Project/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_csv('/content/bmi_train.csv')
df.head()
# Out:
#   Gender  Height  Weight  Index
# 0   Male     161      89      4
# 1   Male     179     127      4
# 2   Male     172     139      5
# 3   Male     153     104      5
# 4   Male     165      68      2

# %%
include=['object','float','int']
perc=[.20, .40, .60, .80]
df.describe(include=include, percentiles=perc)
# Out:
#        Gender      Height      Weight       Index
# count     400  400.000000  400.000000  400.000000
# unique      2         NaN         NaN         NaN
# top      Male         NaN         NaN         NaN
# freq      200         NaN         NaN         NaN
# mean      NaN  170.362500  106.060000    3.737500
# std       NaN   16.574011   32.362242    1.370507
# min       NaN  140.000000   50.000000    0.000000
# 20%       NaN  153.000000   73.000000    2.000000
# 40%       NaN  166.000000   95.600000    4.000000
# 50%       NaN  171.000000  106.500000    4.000000
# 60%       NaN  178.000000  116.400000    4.000000
# 80%       NaN  186.000000  140.200000    5.000000
# max       NaN  199.000000  160.000000    5.000000

# %%
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
import seaborn as sns
corr_matrix=df.select_dtypes(include=['number']).corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
for column in df.columns:
  unique_values = df[column].unique()
  print(f"Unique values in column '{column}':")
  print(unique_values)
  print()
# Out:
# Unique values in column 'Gender':
# ['Male' 'Female']
#
# Unique values in column 'Height':
# [161 179 172 153 165 182 142 158 194 178 155 151 181 147 146 157 173 170
#  190 168 188 162 185 192 152 169 140 141 191 197 163 189 186 195 148 150
#  184 154 144 177 167 145 193 187 183 149 171 180 176 159 166 143 196 198
#  156 160 164 174 199 175]
#
# Unique values in column 'Weight':
# [ 89 127 139 104  68  92 108 130  71 153 107  57  64  80 126 159 155  56
#   82 102 118 140  78 123 115  52  90 142 103  54 105  67 129  86  96 119
#  131 141  76 110 143  70  95  77 152 157 112 111  50 106 160 150  63 117
#   79  58  94  85  59  84  53 144 121  66 125  60 114 151 120 100  55 156
#  147 137  83  74 124  88 133  61  87 145  81 109 146  69 149 138  73  98
#  128  91 135  97 136 101 154  62 158 132  99  65 122  93  75  51 116  72
#  148 134]
#
# Unique values in column 'Index':
# [4 5 2 3 1 0]

# %%
sns.boxplot(x=df['Weight'])
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('our first plot')
plt.figure(figsize=(8,6))
plt.xlabel('Height')
plt.ylabel('Weight')
sns.scatterplot(x='Height', y='Weight', data=df, color='blue')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler=MinMaxScaler()
df['standardscaled_weight']=scaler.fit_transform(df[['Weight']])
df.head()
# Out:
#   Gender  Height  Weight  Index  standardscaled_weight
# 0   Male     161      89      4               0.354545
# 1   Male     179     127      4               0.700000
# 2   Male     172     139      5               0.809091
# 3   Male     153     104      5               0.490909
# 4   Male     165      68      2               0.163636

# %%
minmaxscaler=MinMaxScaler()
df['minmaxscaled_weight']=minmaxscaler.fit_transform(df[['Weight']])
df
# Out:
#     Gender  Height  Weight  Index  standardscaled_weight  minmaxscaled_weight
# 0     Male     161      89      4               0.354545             0.354545
# 1     Male     179     127      4               0.700000             0.700000
# 2     Male     172     139      5               0.809091             0.809091
# 3     Male     153     104      5               0.490909             0.490909
# 4     Male     165      68      2               0.163636             0.163636
# ..     ...     ...     ...    ...                    ...                  ...
# 395   Male     166     160      5               1.000000             1.000000
# 396   Male     145     130      5               0.727273             0.727273
# 397   Male     178     138      5               0.800000             0.800000
# 398   Male     168     158      5               0.981818             0.981818
# 399   Male     161     155      5               0.954545             0.954545
#
# [400 rows x 6 columns]

# %%
df=pd.get_dummies(df, columns=['Gender'])
df
# Out:
#      Height  Weight  Index  standardscaled_weight  minmaxscaled_weight  \
# 0       161      89      4               0.354545             0.354545
# 1       179     127      4               0.700000             0.700000
# 2       172     139      5               0.809091             0.809091
# 3       153     104      5               0.490909             0.490909
# 4       165      68      2               0.163636             0.163636
# ..      ...     ...    ...                    ...                  ...
# 395     166     160      5               1.000000             1.000000
# 396     145     130      5               0.727273             0.727273
# 397     178     138      5               0.800000             0.800000
# 398     168     158      5               0.981818             0.981818
# 399     161     155      5               0.954545             0.954545
#
#      Gender_Female  Gender_Male
# 0            False         True
# 1            False         True
# ...

# %%
#label and coding
from sklearn.preprocessing import LabelEncoder
LabelEncoder=LabelEncoder()
df['Gender_Female']=LabelEncoder.fit_transform(df['Gender_Female'])
df['Gender_Male']=LabelEncoder.fit_transform(df['Gender_Male'])
df
# Out:
#      Height  Weight  Index  standardscaled_weight  minmaxscaled_weight  \
# 0       161      89      4               0.354545             0.354545
# 1       179     127      4               0.700000             0.700000
# 2       172     139      5               0.809091             0.809091
# 3       153     104      5               0.490909             0.490909
# 4       165      68      2               0.163636             0.163636
# ..      ...     ...    ...                    ...                  ...
# 395     166     160      5               1.000000             1.000000
# 396     145     130      5               0.727273             0.727273
# 397     178     138      5               0.800000             0.800000
# 398     168     158      5               0.981818             0.981818
# 399     161     155      5               0.954545             0.954545
#
#      Gender_Female  Gender_Male
# 0                0            1
# 1                0            1
# ...

# %%
#saving the preprocessed data in csv
df.to_csv('preprocessed_data.csv', index=False)
print('done')
# Out:
# done

# %%
# k means clustering - elbow
import numpy as np
import sklearn
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
df=pd.read_csv('/content/preprocessed_data.csv')
df.head()
WCSS=[]
for i in range(1,11):
  kmeans=KMeans(n_clusters=i, init='k-means++', random_state=42)
  kmeans.fit(df)
  WCSS.append(kmeans.inertia_)

  #you can now proceed to plot the elbow methodgraph if needed
 # Move plotting outside the loop
plt.plot(range(1,11), WCSS) # Match x and y lengths
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
  #visualize every clusters
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# Generate sample data
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# Plotting the clusters
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

# Plotting the centroids
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, alpha=0.75, marker='X')

plt.title("Cluster Plot with Different Colors")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
